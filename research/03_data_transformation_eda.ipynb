# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %%
import os

# %%
os.chdir("../")

# %%
# %pwd
# Out:
# 'd:\\MLops\\DataScienceProject_1\\Health_premium_prediction'

# %%
df = pd.read_csv("artifacts/data_ingestion/data.csv")

# %% [markdown]
# # Numerical Data analysis

# %%
df.isna().sum()
# Out:
# Age                       0
# Gender                    0
# Region                    0
# Marital_status            0
# Number Of Dependants      0
# BMI_Category              0
# Smoking_Status           11
# Employment_Status         2
# Income_Level             13
# Income_Lakhs              0
# Medical History           0
# Insurance_Plan            0
# Annual_Premium_Amount     0
# dtype: int64

# %%
df.dropna(inplace=True) 
df.head()
print(df.isna().sum())
# Out:
# Age                      0
# Gender                   0
# Region                   0
# Marital_status           0
# Number Of Dependants     0
# BMI_Category             0
# Smoking_Status           0
# Employment_Status        0
# Income_Level             0
# Income_Lakhs             0
# Medical History          0
# Insurance_Plan           0
# Annual_Premium_Amount    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.describe()
# Out:
#                 Age  Number Of Dependants  Income_Lakhs  Annual_Premium_Amount
# count  49976.000000          49976.000000  49976.000000           49976.000000
# mean      34.591764              1.711842     23.021150           15766.810189
# std       15.000378              1.498195     24.221794            8419.995271
# min       18.000000             -3.000000      1.000000            3501.000000
# 25%       22.000000              0.000000      7.000000            8607.750000
# 50%       31.000000              2.000000     17.000000           13928.000000
# 75%       45.000000              3.000000     31.000000           22273.500000
# max      356.000000              5.000000    930.000000           43471.000000

# %%
df.columns = df.columns.str.replace(' ', '_').str.lower() # replacing the " " in cloumn names to '_'

# %%
df[df.number_of_dependants<0].shape
# Out:
# (72, 13)

# %%
df[df.number_of_dependants<0]['number_of_dependants'].unique()
# Out:
# array([-3, -1])

# %%
df[df.number_of_dependants==-3].shape
# Out:
# (32, 13)

# %%
df['number_of_dependants'] = abs(df['number_of_dependants']) 

df['number_of_dependants'].describe()
# Out:
# count    49976.000000
# mean         1.717284
# std          1.491953
# min          0.000000
# 25%          0.000000
# 50%          2.000000
# 75%          3.000000
# max          5.000000
# Name: number_of_dependants, dtype: float64

# %%
sns.boxplot(x = df['age'])

plt.show()

# %% [markdown]
# above box plot clearly shows that thre are about 5 outliers in our age column

# %%
numeric_columns = df.select_dtypes(['float64','int64']).columns

numeric_columns
# Out:
# Index(['age', 'number_of_dependants', 'income_lakhs', 'annual_premium_amount'], dtype='object')

# %%
for col in numeric_columns :
    sns.boxplot(x = df[col]) 
    plt.show()


#sns.boxplot(x = df[numeric_columns])

#plt.show

# %%
df_1 = df[df.age<=100].copy()

# %%
df_1.describe()
# Out:
#                 age  number_of_dependants  income_lakhs  annual_premium_amount
# count  49918.000000          49918.000000  49918.000000           49918.000000
# mean      34.401839              1.717617     23.025141           15766.589286
# std       13.681600              1.492074     24.227912            8419.137327
# min       18.000000              0.000000      1.000000            3501.000000
# 25%       22.000000              0.000000      7.000000            8608.000000
# 50%       31.000000              2.000000     17.000000           13928.000000
# 75%       45.000000              3.000000     31.000000           22272.000000
# max       72.000000              5.000000    930.000000           43471.000000

# %%
def get_iqr_bounds(col):
    Q1,Q3 = col.quantile([0.25,0.75]) 
    IQR = Q3 - Q1 

    lower_bound = Q1 - 1.5*IQR 
    upper_bound = Q3 + 1.5*IQR 

    return lower_bound, upper_bound

# %%
get_iqr_bounds(df_1['income_lakhs'])
# Out:
# (-29.0, 67.0)

# %% [markdown]
# In the above case we can see that the lower bound suggested is 67 lakhs. But 67 in India is not very high. People earn heigher that 67 lakhs in India. So it cannot be a upperbound.
#
# Instead I feel a upperbound of 1 cr is good enough.

# %%
df_1[df_1['income_lakhs']>100].shape
# Out:
# (10, 13)

# %% [markdown]
# only 10 people have income greater than 1 cr, Hence we can drop it.

# %%
df_2 = df_1[df_1['income_lakhs']<=100]

# %%
df_2['income_lakhs'].describe()
# Out:
# count    49908.000000
# mean        22.889897
# std         22.170699
# min          1.000000
# 25%          7.000000
# 50%         17.000000
# 75%         31.000000
# max        100.000000
# Name: income_lakhs, dtype: float64

# %% [markdown]
# ### Distribution analysis of the data

# %%
fig, axs = plt.subplots(nrows=2, ncols=2, figsize=(10, 8)) 

for i, column in enumerate(numeric_columns):
    ax = axs[i//2, i%2]  
    sns.histplot(df_2[column], kde=True, ax=ax)
    ax.set_title(column)

plt.tight_layout()
plt.show()

# %% [markdown]
# The above data shows right skewness. This right skewness is normal for data which involves income and other factors.

# %%
numeric_features = ['age', 'income_lakhs', 'number_of_dependants']

fig, axes = plt.subplots(1, len(numeric_features), figsize=(18, 6))  # Adjust figure size as necessary

for ax, column in zip(axes, numeric_features):
    sns.scatterplot(x=df_2[column], y=df_2['annual_premium_amount'], ax=ax)
    ax.set_title(f'{column} vs. Annual Premium Amount')
    ax.set_xlabel(column)
    ax.set_ylabel('Annual Premium Amount')

plt.tight_layout()  # Adjust layout
plt.show()

# %% [markdown]
# # Categorical data analysis

# %%
categorical_cols = ['gender', 'region', 'marital_status', 'bmi_category', 'smoking_status', 'employment_status', 'income_level', 'medical_history', 'insurance_plan']

for col in categorical_cols:
    print(col , ':', df_2[col].unique())
# Out:
# gender : ['Male' 'Female']
# region : ['Northwest' 'Southeast' 'Northeast' 'Southwest']
# marital_status : ['Unmarried' 'Married']
# bmi_category : ['Normal' 'Obesity' 'Overweight' 'Underweight']
# smoking_status : ['No Smoking' 'Regular' 'Occasional' 'Smoking=0' 'Does Not Smoke'
#  'Not Smoking']
# employment_status : ['Salaried' 'Self-Employed' 'Freelancer']
# income_level : ['<10L' '10L - 25L' '> 40L' '25L - 40L']
# medical_history : ['Diabetes' 'High blood pressure' 'No Disease'
#  'Diabetes & High blood pressure' 'Thyroid' 'Heart disease'
#  'High blood pressure & Heart disease' 'Diabetes & Thyroid'
#  'Diabetes & Heart disease']
# insurance_plan : ['Bronze' 'Silver' 'Gold']

# %% [markdown]
# 1. We can see that in smoking_status col 'No Smoking','Smoking=0' ,'Does Not Smoke','Not Smoking' have same meaning, but are represented differently.
#
# Rest all data seems to be correct

# %%
df_2['smoking_status'].replace({
    'Smoking=0':'No Smoking',
    'Does Not Smoke': 'No Smoking',
    'Not Smoking': 'No Smoking'
}, inplace = True)

df_2['smoking_status'].unique()
# Out:
# C:\Users\Ujjwal\AppData\Local\Temp\ipykernel_15344\3819073252.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_2['smoking_status'].replace({
# C:\Users\Ujjwal\AppData\Local\Temp\ipykernel_15344\3819073252.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2['smoking_status'].replace({
# ...

# %%
all_columns = df.columns
all_columns
# Out:
# Index(['age', 'gender', 'region', 'marital_status', 'number_of_dependants',
#        'bmi_category', 'smoking_status', 'employment_status', 'income_level',
#        'income_lakhs', 'medical_history', 'insurance_plan',
#        'annual_premium_amount'],
#       dtype='object')

# %%
crosstab = pd.crosstab(df_2['income_level'], df_2['insurance_plan'])
print(crosstab)

crosstab.plot(kind='bar', stacked=True) 
'''
This above line 
makes a bar for each income_level (Low, Medium, High)
Each bar is divided into colored blocks:
Bottom = Basic count
Middle = Standard
Top = Premium
'''
plt.title('Income vs Plan')
plt.ylabel('Count')
plt.show()
# Out:
# insurance_plan  Bronze  Gold  Silver
# income_level
# 10L - 25L         5307  3880    5182
# 25L - 40L         3683  2840    3750
# <10L             12226   931    5486
# > 40L              329  3653    2641

# %%
sns.heatmap(crosstab, annot=True, cmap='coolwarm',fmt="d")
plt.title('Heatmap of Income vs Plan')
plt.show()

# %% [markdown]
# # Feature Engineeering

# %%
risk_scores = {
    "diabetes": 6,
    "heart disease": 8,
    "high blood pressure":6,
    "thyroid": 5,
    "no disease": 0,
    "none":0
}

# %%
df_2[['disease1', 'disease2']] = df_2['medical_history'].str.split(" & ", expand=True).apply(lambda x: x.str.lower())
df_2['disease1'].fillna('none', inplace=True)
df_2['disease2'].fillna('none', inplace=True)
df_2['total_risk_score'] = 0
# Out:
# C:\Users\Ujjwal\AppData\Local\Temp\ipykernel_15344\3790894870.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2[['disease1', 'disease2']] = df_2['medical_history'].str.split(" & ", expand=True).apply(lambda x: x.str.lower())
# C:\Users\Ujjwal\AppData\Local\Temp\ipykernel_15344\3790894870.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2[['disease1', 'disease2']] = df_2['medical_history'].str.split(" & ", expand=True).apply(lambda x: x.str.lower())
# ...

# %%
for disease in ['disease1', 'disease2']:
    df_2['total_risk_score'] += df_2[disease].map(risk_scores)

# Normalize the risk score to a range of 0 to 1
max_score = df_2['total_risk_score'].max()
min_score = df_2['total_risk_score'].min()
df_2['normalized_risk_score'] = (df_2['total_risk_score'] - min_score) / (max_score - min_score)
df_2.head(2)
# Out:
# C:\Users\Ujjwal\AppData\Local\Temp\ipykernel_15344\4166724497.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2['total_risk_score'] += df_2[disease].map(risk_scores)
# C:\Users\Ujjwal\AppData\Local\Temp\ipykernel_15344\4166724497.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2['total_risk_score'] += df_2[disease].map(risk_scores)
# C:\Users\Ujjwal\AppData\Local\Temp\ipykernel_15344\4166724497.py:7: SettingWithCopyWarning:
# ...

# %%
df_2['insurance_plan'] = df_2['insurance_plan'].map({'Bronze': 1, 'Silver': 2, 'Gold': 3})
# Out:
# C:\Users\Ujjwal\AppData\Local\Temp\ipykernel_15344\3484333659.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2['insurance_plan'] = df_2['insurance_plan'].map({'Bronze': 1, 'Silver': 2, 'Gold': 3})

# %%
df_2.head(2)
# Out:
#    age  gender     region marital_status  number_of_dependants bmi_category  \
# 0   26    Male  Northwest      Unmarried                     0       Normal
# 1   29  Female  Southeast        Married                     2      Obesity
#
#   smoking_status employment_status income_level  income_lakhs medical_history  \
# 0     No Smoking          Salaried         <10L             6        Diabetes
# 1        Regular          Salaried         <10L             6        Diabetes
#
#    insurance_plan  annual_premium_amount  disease1 disease2  total_risk_score  \
# 0               1                   9053  diabetes     none                 6
# 1               1                  16339  diabetes     none                 6
#
#    normalized_risk_score
# 0               0.428571
# 1               0.428571

# %%
df_2['income_level'] = df_2['income_level'].map({'<10L':1, '10L - 25L': 2, '25L - 40L':3, '> 40L':4})

df_2.head(3)
# Out:
# C:\Users\Ujjwal\AppData\Local\Temp\ipykernel_15344\2166947646.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2['income_level'] = df_2['income_level'].map({'<10L':1, '10L - 25L': 2, '25L - 40L':3, '> 40L':4})
#    age  gender     region marital_status  number_of_dependants bmi_category  \
# 0   26    Male  Northwest      Unmarried                     0       Normal
# 1   29  Female  Southeast        Married                     2      Obesity
# 2   49  Female  Northeast        Married                     2       Normal
#
#   smoking_status employment_status  income_level  income_lakhs  \
# 0     No Smoking          Salaried             1             6
# 1        Regular          Salaried             1             6
# ...

# %%
# one hot encoding 
nominal_cols = ['gender', 'region', 'marital_status', 'bmi_category', 'smoking_status', 'employment_status']
df_3 = pd.get_dummies(df_2, columns=nominal_cols, drop_first=True, dtype=int)
df_3.head(3)
# Out:
#    age  number_of_dependants  income_level  income_lakhs      medical_history  \
# 0   26                     0             1             6             Diabetes
# 1   29                     2             1             6             Diabetes
# 2   49                     2             2            20  High blood pressure
#
#    insurance_plan  annual_premium_amount             disease1 disease2  \
# 0               1                   9053             diabetes     none
# 1               1                  16339             diabetes     none
# 2               2                  18164  high blood pressure     none
#
#    total_risk_score  ...  region_Southeast  region_Southwest  \
# 0                 6  ...                 0                 0
# 1                 6  ...                 1                 0
# 2                 6  ...                 0                 0
#
#    marital_status_Unmarried  bmi_category_Obesity  bmi_category_Overweight  \
# ...

# %%
df_4 = df_3.drop(['medical_history','disease1', 'disease2', 'total_risk_score'], axis=1)
df_4.head(3)
# Out:
#    age  number_of_dependants  income_level  income_lakhs  insurance_plan  \
# 0   26                     0             1             6               1
# 1   29                     2             1             6               1
# 2   49                     2             2            20               2
#
#    annual_premium_amount  normalized_risk_score  gender_Male  \
# 0                   9053               0.428571            1
# 1                  16339               0.428571            0
# 2                  18164               0.428571            0
#
#    region_Northwest  region_Southeast  region_Southwest  \
# 0                 1                 0                 0
# 1                 0                 1                 0
# 2                 0                 0                 0
#
#    marital_status_Unmarried  bmi_category_Obesity  bmi_category_Overweight  \
# 0                         1                     0                        0
# ...

# %%
df_4.columns
# Out:
# Index(['age', 'number_of_dependants', 'income_level', 'income_lakhs',
#        'insurance_plan', 'annual_premium_amount', 'normalized_risk_score',
#        'gender_Male', 'region_Northwest', 'region_Southeast',
#        'region_Southwest', 'marital_status_Unmarried', 'bmi_category_Obesity',
#        'bmi_category_Overweight', 'bmi_category_Underweight',
#        'smoking_status_Occasional', 'smoking_status_Regular',
#        'employment_status_Salaried', 'employment_status_Self-Employed'],
#       dtype='object')

# %% [markdown]
# Since Multicolinearity causes a problem, hence we will like to make a correlation matrix to look into this

# %%
cm = df_4.corr()

plt.figure(figsize=(20,12))
sns.heatmap(cm, annot=True)
plt.xticks(rotation=45, ha='right')
plt.yticks(rotation=0)
plt.tight_layout()
plt.show()

# %% [markdown]
# I would calculate the VIF to know that which features to keep and which to remove

# %%
X = df_4.drop('annual_premium_amount', axis = 'columns') 
y = df_4['annual_premium_amount']

# %%
from sklearn.preprocessing import MinMaxScaler

cols_to_scale = ['age','number_of_dependants', 'income_level',  'income_lakhs', 'insurance_plan']
scaler = MinMaxScaler()

X[cols_to_scale] = scaler.fit_transform(X[cols_to_scale])
X.describe()
# Out:
#                 age  number_of_dependants  income_level  income_lakhs  \
# count  49908.000000          49908.000000  49908.000000  49908.000000
# mean       0.303733              0.343528      0.365900      0.221110
# std        0.253363              0.298406      0.349711      0.223946
# min        0.000000              0.000000      0.000000      0.000000
# 25%        0.074074              0.000000      0.000000      0.060606
# 50%        0.240741              0.400000      0.333333      0.161616
# 75%        0.500000              0.600000      0.666667      0.303030
# max        1.000000              1.000000      1.000000      1.000000
#
#        insurance_plan  normalized_risk_score   gender_Male  region_Northwest  \
# count    49908.000000           49908.000000  49908.000000       49908.00000
# mean         0.397401               0.291831      0.549631           0.20093
# std          0.392459               0.287420      0.497536           0.40070
# ...

# %%
# Calcumate VIF -> Variance Invariance Factor

# %%
# dropping 
X.columns
# Out:
# Index(['age', 'number_of_dependants', 'income_level', 'income_lakhs',
#        'insurance_plan', 'normalized_risk_score', 'gender_Male',
#        'region_Northwest', 'region_Southeast', 'region_Southwest',
#        'marital_status_Unmarried', 'bmi_category_Obesity',
#        'bmi_category_Overweight', 'bmi_category_Underweight',
#        'smoking_status_Occasional', 'smoking_status_Regular',
#        'employment_status_Salaried', 'employment_status_Self-Employed'],
#       dtype='object')

# %%
X.drop('income_level', axis='columns', inplace=True)

# %%
X.head()
# Out:
#         age  number_of_dependants  income_lakhs  insurance_plan  \
# 0  0.148148                   0.0      0.050505             0.0
# 1  0.203704                   0.4      0.050505             0.0
# 2  0.574074                   0.4      0.191919             0.5
# 3  0.222222                   0.6      0.767677             1.0
# 4  0.000000                   0.0      0.989899             0.5
#
#    normalized_risk_score  gender_Male  region_Northwest  region_Southeast  \
# 0               0.428571            1                 1                 0
# 1               0.428571            0                 0                 1
# 2               0.428571            0                 0                 0
# 3               0.000000            0                 0                 1
# 4               0.428571            1                 0                 0
#
#    region_Southwest  marital_status_Unmarried  bmi_category_Obesity  \
# ...

# %%
y.describe()
# Out:
# count    49908.000000
# mean     15765.739641
# std       8418.674061
# min       3501.000000
# 25%       8608.000000
# 50%      13928.000000
# 75%      22270.500000
# max      43471.000000
# Name: annual_premium_amount, dtype: float64

# %%
X.columns
# Out:
# Index(['age', 'number_of_dependants', 'income_lakhs', 'insurance_plan',
#        'normalized_risk_score', 'gender_Male', 'region_Northwest',
#        'region_Southeast', 'region_Southwest', 'marital_status_Unmarried',
#        'bmi_category_Obesity', 'bmi_category_Overweight',
#        'bmi_category_Underweight', 'smoking_status_Occasional',
#        'smoking_status_Regular', 'employment_status_Salaried',
#        'employment_status_Self-Employed'],
#       dtype='object')

# %%
X.describe()
# Out:
#                 age  number_of_dependants  income_lakhs  insurance_plan  \
# count  49908.000000          49908.000000  49908.000000    49908.000000
# mean       0.303733              0.343528      0.221110        0.397401
# std        0.253363              0.298406      0.223946        0.392459
# min        0.000000              0.000000      0.000000        0.000000
# 25%        0.074074              0.000000      0.060606        0.000000
# 50%        0.240741              0.400000      0.161616        0.500000
# 75%        0.500000              0.600000      0.303030        0.500000
# max        1.000000              1.000000      1.000000        1.000000
#
#        normalized_risk_score   gender_Male  region_Northwest  \
# count           49908.000000  49908.000000       49908.00000
# mean                0.291831      0.549631           0.20093
# std                 0.287420      0.497536           0.40070
# min                 0.000000      0.000000           0.00000
# ...
